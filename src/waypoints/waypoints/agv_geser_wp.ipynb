# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
wp_path = "wp1feb2021.npy"
wp = np.load(wp_path)

# %%
wp2 = np.copy(wp)
wp2[:,0] = wp2[:,0] - 1

# %%
plt.scatter(wp[:,0], wp[:,1], label="wp")
plt.scatter(wp2[:,0], wp2[:,1], label="wp2")
plt.legend()

# %%
np.save(wp_path, wp2)
